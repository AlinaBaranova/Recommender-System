# %%
import networkx as nx
import json
from nltk import word_tokenize
from nltk.corpus import stopwords
import sys
import gensim, logging
import re
import os
import treetaggerwrapper
import random
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Slow version of gensim.models.doc2vec is being used

# %% [markdown]
# Загружаем топики; создаём словарь вида: обработанный топик - исходный топик

# %% [markdown]
# Лемматизатор:

# %%
tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')

# %% [markdown]
# Обработка включает в себя: токенизацию, удаление знаков препинания и стопслов, лемматизацию, сведение всех слов к нижнему регистру:

# %%
def analyze_topic(topic):
    stop = stopwords.words('english')

    tokens = word_tokenize(topic)
    punct = ',.()":;--&?!\'s'
    tokens = [token for token in tokens if token not in punct]
    tokens = [token for token in tokens if token not in stop]
    new_tokens = []
    for token in tokens:
        lemma = tagger.tag_text(token)[0].split('\t')[-1]
        if lemma != '@card@':
            new_tokens.append(lemma)
        else:
            new_tokens.append(token)
    
    return ' '.join(new_tokens).lower()

# %% [markdown]
# Загружаем топики из графа:

# %%
G = nx.read_gexf('topics.gexf')

# %%
topics = G.nodes()

# %% [markdown]
# Обрабатываем и записываем в файл:

# %%
new_topics = {}
for topic in topics:
    new_topics[analyze_topic(topic)] = topic

# %%
new_topics
# Out:
# {'lisbon earthquake portugal 1755': 'Lisbon Earthquake, Portugal, 1755',
#  'earthquake': 'Earthquakes',
#  'woman': 'Women',
#  'ops roman deity': 'Ops (Roman deity)',
#  'snake': 'Snakes',
#  'eve biblical figure': 'Eve (Biblical figure)',
#  'temptation': 'Temptation',
#  'weave': 'Weaving',
#  'penelope greek mythology': 'Penelope (Greek mythology)',
#  'murder': 'Murder',
#  'tombs sepulchral monument': 'Tombs & sepulchral monuments',
#  'elephant': 'Elephants',
#  'book jacket': 'Book jackets',
#  'animal fiction': 'Animals--Fiction',
#  'book cover': 'Book covers',
#  'domestic life': 'Domestic life',
#  'dwelling': 'Dwellings',
#  'oromo african people': 'Oromo (African people)',
#  'canyon': 'Canyons',
#  'teenager': 'Teenagers',
#  'peddler': 'Peddlers',
#  'market': 'Markets',
#  'street': 'Streets',
#  'art japanese': 'Arts, Japanese',
#  'photography': 'Photography',
#  'jews': 'Jews',
#  'theater': 'Theaters',
#  'costume': 'Costume -- ',
#  'art modern': 'Art, Modern',
#  'art deco': 'Art deco',
#  'decoration ornament': 'Decoration and ornament',
#  'letter-pictures': 'Letter-pictures',
#  'postal service': 'Postal service',
#  'building': 'Building',
#  'road': 'Roads',
#  'house': 'Houses',
#  'mountain': 'Mountains',
#  'settlement': 'Settlements',
#  'castles palace': 'Castles & palaces',
#  'telegraph': 'Telegraph',
#  'landscape architecture facility': 'Landscape architecture facilities',
#  'architecture': 'Architecture',
#  'landscape pavilion': 'Landscape pavilions',
#  'fula african people': 'Fula (African people)',
#  'tramp': 'Tramps',
#  'boys': 'Boys',
#  'sudanese': 'Sudanese',
#  'muslims': 'Muslims',
#  'clothing dress': 'Clothing and dress',
#  'hausa african people': 'Hausa (African people)',
#  'river': 'Rivers',
#  'canoe': 'canoes',
#  'queens': 'Queens',
#  'african': 'African',
#  'nupe african people': 'Nupe (African people)',
#  'village': 'Villages',
#  'nobility': 'Nobility',
#  'captive': 'Captives',
#  'rite ceremony': 'Rites & ceremonies',
#  'yoruba african people': 'Yoruba (African people)',
#  'turkmen clothing dress': 'Turkmen -- Clothing & dress',
#  'turkmen': 'Turkmen',
#  'water carrier': 'Water carriers',
#  'forts fortification': 'Forts & fortifications',
#  'yurt': 'Yurts',
#  'circus animal': 'Circus animals',
#  'people associate entertainment sport': 'People associated with entertainment & sports',
#  'goat': 'Goats',
#  'prisoner war': 'Prisoners of war',
#  'cavalry': 'Cavalry',
#  'milkweed': 'Milkweeds',
#  'butterfly': 'Butterflies',
#  'museum': 'Museums',
#  'stairway': 'Stairways',
#  'icon': 'Icons',
#  'religious article': 'Religious articles',
#  'grille': 'Grilles',
#  'sculpture': 'Sculpture',
#  'russian': 'Russian',
#  'armory': 'Armories',
#  'crosse': 'Crosses',
#  'religious facility': 'Religious facilities',
#  'candlestick': 'Candlesticks',
#  'room space': 'Rooms & spaces',
#  'hut': 'Huts',
#  'boat 1800-1899': 'Boats -- 1800-1899',
#  'workshop recipe': 'Workshop recipes',
#  'industrial art': 'Industrial arts',
#  'intellectual': 'Intellectuals',
#  'upanishads': 'Upanishads',
#  'tripod': 'Tripods',
#  'player piano': 'Player piano',
#  'camera operator': 'Camera operators',
#  'percussion instrument': 'Percussion instruments',
#  'monkey': 'Monkeys',
#  'shakuhachi': 'Shakuhachi',
#  'musical instrument': 'Musical instruments',
#  'piano': 'Piano',
#  'horse team': 'Horse teams',
#  'home haunt': 'Home and haunts',
#  'caricature cartoon': 'Caricatures and cartoons',
#  'drum musical instrument': 'Drums (Musical instruments)',
#  'social life custom': 'Social life & customs',
#  'mother son': 'Mothers and sons',
#  'migrant laborer': 'Migrant laborers',
#  'african americans': 'African Americans',
#  'cotton picker': 'Cotton pickers',
#  'sign notice': 'Signs (Notices)',
#  'woman agricultural laborer': 'Women agricultural laborers',
#  'mother child': 'Mother and child',
#  'cotton plantation worker': 'Cotton plantation workers',
#  'slave ship': 'Slave ships',
#  'slavery': 'Slavery',
#  'family': 'Family',
#  'prayer': 'Prayer',
#  'auction': 'Auctions',
#  'fugitive slave': 'Fugitive slaves',
#  'slave': 'Slaves',
#  'plantation': 'Plantations',
#  'shackle': 'shackles',
#  'whipping': 'whipping',
#  'dead person': 'Dead persons',
#  'grief': 'Grief',
#  'god': 'God',
#  'whip': 'Whips',
#  'road construction': 'Road construction',
#  'chart diagram etc': 'Charts, diagrams, etc',
#  'dancer': 'Dancers',
#  'windmill': 'Windmills',
#  'church': 'Church',
#  'freedman': 'Freedmen',
#  'african american woman': 'African American women',
#  'canned food': 'Canned foods',
#  'home food processing': 'Home food processing',
#  'interior': 'Interiors',
#  'cotton': 'Cotton',
#  'labor housing': 'Labor housing',
#  'farm': 'Farms',
#  'memorial day': 'Memorial Day',
#  'meadows': 'Meadows',
#  'pie': 'Pies',
#  'kitchens': 'Kitchens',
#  'valley': 'Valleys',
#  'farmhouse': 'Farmhouses',
#  'community life': 'Community life',
#  'mormon church': 'Mormon churches',
#  'bouquet': 'Bouquets',
#  'architectural decoration ornament': 'Architectural decorations & ornaments',
#  'houghton hall england': 'Houghton Hall (England)',
#  'ceiling': 'Ceilings',
#  'chimneypiece': 'Chimneypieces',
#  'stable': 'Stables',
#  'bust': 'busts',
#  'gardens': 'Gardens',
#  'zande african people': 'Zande (African people)',
#  'human body': 'Human body',
#  'kongo african people': 'Kongo (African people)',
#  'city town': 'Cities and towns',
#  'lakes pond': 'Lakes & ponds',
#  'mangbetu african people': 'Mangbetu (African people)',
#  'escutcheon heraldry': 'Escutcheons (Heraldry)',
#  'hills': 'Hills',
#  'mpongwe african people': 'Mpongwe (African people)',
#  'messenger': 'Messengers',
#  'thatch roof': 'Thatched roofs',
#  'boat': 'Boats',
#  'shields': 'Shields',
#  'warrior': 'Warriors',
#  'horseback ride': 'horseback riding',
#  'spears': 'Spears',
#  'kanembu african people': 'Kanembu (African people)',
#  'harbors': 'Harbors',
#  'slave trade': 'Slave trade',
#  'waterway': 'Waterways',
#  'kru african people': 'Kru (African people)',
#  'ethnic group': 'Ethnic groups',
#  'rifle': 'Rifles',
#  'creole sierra leone': 'Creoles (Sierra Leone)',
#  'child': 'Children',
#  'mother': 'Mothers',
#  'canal': 'Canals',
#  'fang west african people': 'Fang (West African people)',
#  'palm': 'Palms',
#  'railroad station': 'Railroad stations',
#  'man': 'Men',
#  'barge': 'Barges',
#  'sere african people': 'Serer (African people)',
#  'bangala african people': 'Bangala (African people)',
#  'tribal chief': 'Tribal chiefs',
#  'bijago african people': 'Bijago (African people)',
#  'termite': 'Termites',
#  'ruler': 'rulers',
#  'wall': 'Walls',
#  'bambara african people': 'Bambara (African people)',
#  'turban': 'Turbans',
#  'couple': 'Couples',
#  'rock formation': 'Rock formations',
#  'anyi african people': 'Anyi (African people)',
#  'islands': 'Islands',
#  'factory': 'Factories',
#  'waterfall': 'Waterfalls',
#  'northern lunda african people': 'Northern Lunda (African people)',
#  'fisherman': 'Fishermen',
#  'hairdressing': 'Hairdressing',
#  'sultan': 'Sultans',
#  'fetish ceremonial object': 'Fetishes (Ceremonial objects)',
#  'stone': 'Stoning',
#  'toucouleur african people': 'Toucouleur (African people)',
#  'mission': 'Missions',
#  'hairstyle': 'Hairstyles',
#  'wolof african people': 'Wolof (African people)',
#  'felup african people': 'Felup (African people)',
#  'history': 'History',
#  'health aspect': 'Health aspects',
#  'military hospital': 'Military hospitals',
#  'soldier home': "Soldiers' homes",
#  'cart wagon': 'Carts & wagons',
#  'ambulance': 'Ambulances',
#  'military depot': 'Military depots',
#  'battlefield': 'Battlefields',
#  'cemetery': 'Cemeteries',
#  'theological seminary': 'Theological seminaries',
#  'military headquarters': 'Military headquarters',
#  'pontoon bridge': 'Pontoon bridges',
#  'medical aspect war': 'Medical aspects of war',
#  'casualites': 'Casualites',
#  'fort stedman battle petersburg va. 1865': 'Fort Stedman, Battle of, Petersburg, Va., 1865',
#  'military camp': 'Military camps',
#  'sailing ship': 'Sailing ships',
#  'war casualty': 'War casualties',
#  'tent': 'Tents',
#  'bridge': 'Bridges',
#  'organization facility': "Organizations' facilities",
#  'railroad car': 'Railroad cars',
#  'sign symbol': 'Signs and symbols',
#  'eagles': 'Eagles',
#  'hospital': 'Hospital',
#  'african american soldier': 'African American soldiers',
#  'log building': 'Log buildings',
#  'historic building': 'Historic buildings',
#  'post office': 'Post offices',
#  'prison': 'Prisons',
#  'steamboat': 'Steamboats',
#  'world war 1914-1918': 'World War, 1914-1918',
#  'christian art symbolism': 'Christian art and symbolism',
#  'church decoration ornament': 'Church decoration and ornament',
#  'dungeon': 'dungeons',
#  'brain': 'Brain',
#  'medical photography': 'Medical photography',
#  'foot': 'feet',
#  'deer': 'Deer',
#  'monks': 'Monks',
#  'servant': 'Servants',
#  'child labor': 'Child labor',
#  'street cleaning': 'Street cleaning',
#  'laundry': 'Laundry',
#  'game game bird': 'Game & game birds',
#  'hunting': 'Hunting',
#  'animal': 'Animals',
#  'english wit humor': 'English wit and humor',
#  'saint': 'Saints',
#  'magi': 'Magi',
#  'construction': 'Construction',
#  'politics government': 'Politics & government',
#  'periodical': 'Periodicals',
#  'age person': 'Aged persons',
#  'confection': 'Confections',
#  'charity': 'Charities',
#  'singer': 'Singers',
#  'student': 'Students',
#  'african american editor': 'African American editors',
#  'editor': 'Editors',
#  'choir music': 'Choirs (Music)',
#  'chimney sweep': 'Chimney sweeps',
#  'free african americans': 'Free African Americans',
#  'albinus': 'Albinus',
#  'circus show': 'Circuses & shows',
#  'african americans child 1890-1899': 'African Americans -- Children -- 1890-1899',
#  'phonograph industry': 'Phonograph industry',
#  'american': 'American',
#  'ambassador': 'Ambassadors',
#  'clergy': 'Clergy',
#  'preaching': 'Preaching',
#  'african american boy': 'African American boys',
#  'african american mother': 'African American mothers',
#  'creole': 'Creoles',
#  'description travel': 'Description and travel',
#  'harpsichord': 'harpsichords',
#  'commerce': 'Commerce',
#  'embargo 1807-1809': 'Embargo, 1807-1809',
#  'tea trade': 'Tea trade',
#  'commission merchant': 'Commission merchants',
#  'dry-goods': 'Dry-goods',
#  'shipping': 'Shipping',
#  'fur trade': 'Fur trade',
#  'thatch roof building': 'Thatched roof buildings',
#  'haitian': 'Haitian',
#  'soldier': 'Soldiers',
#  'capital punishment': 'Capital punishment',
#  'photography artistic': 'Photography, Artistic',
#  'ballet dancer': 'Ballet dancers',
#  'archer': 'Archers',
#  'bird': 'Birds',
#  'campaign': 'Campaigns',
#  'crimean war 1853-1856': 'Crimean War, 1853-1856',
#  'african american clergy': 'African American clergy',
#  'african american college teacher': 'African American college teachers',
#  'african american baptist': 'African American Baptists',
#  'baptist church': 'Baptist churches',
#  'real estate development': 'Real estate development',
#  'african american farmer': 'African American farmers',
#  'education': 'Education',
#  'public school': 'Public schools',
#  'housing': 'Housing',
#  'african american teacher': 'African American teachers',
#  'wage': 'Wages',
#  'palette': 'Palettes',
#  'color print': 'Color prints',
#  'postal service employee': 'Postal service employees',
#  'african american lawyer': 'African American lawyers',
#  'african american surgeon': 'African American surgeons',
#  'african american politician': 'African American politicians',
#  'african american civic leader': 'African American civic leaders',
#  'african american orator': 'African American orators',
#  'african american author': 'African American authors',
#  'diplomat': 'Diplomats',
#  'suffrage': 'Suffrage',
#  'chaplain': 'Chaplains',
#  'african american man': 'African American men',
#  'general': 'Generals',
#  'public officer': 'Public officers',
#  'african american legislator': 'African American legislators',
#  'african american educator': 'African American educators',
#  'african american physician': 'African American physicians',
#  'police brutality': 'Police brutality',
#  'african american accountant': 'African American accountants',
#  'guitarist': 'Guitarists',
#  'electric guitar': 'electric guitars',
#  'flag': 'Flags',
#  'cash register': 'Cash registers',
#  'bookstore': 'Bookstores',
#  'leisure': 'Leisure',
#  'yoga exercise': 'Yoga (Exercise)',
#  'old people': 'Older people',
#  'eyeglass': 'Eyeglasses',
#  'ballroom dancing': 'Ballroom dancing',
#  'dance floor': 'Dance floors',
#  'buddhism': 'Buddhism',
#  'class group student': 'Classes (Groups of students)',
#  'african american university college': 'African American universities and colleges',
#  'african american college student': 'African American college students',
#  'photography education': 'Photography in education',
#  'college trustee': 'College trustees',
#  'college teacher': 'College teachers',
#  'petition': 'Petitions',
#  'lion': 'Lion',
#  'beavers': 'Beavers',
#  'black': 'Blacks',
#  'basket': 'Baskets',
#  'sheep': 'Sheep',
#  'fountain': 'Fountains',
#  'merchant': 'Merchants',
#  'sailboat': 'Sailboats',
#  'west indians': 'West Indians',
#  'woman merchant': 'Women merchants',
#  'hindu': 'Hindus',
#  'wells': 'Wells',
#  'headdress': 'headdresses',
#  'hindu woman': 'Hindu women',
#  'plantation life': 'Plantation life',
#  'african american child': 'African American children',
#  'social condition': 'Social conditions',
#  'united state': 'United States',
#  'guitar': 'Guitar',
#  'courtship': 'Courtship',
#  'african american girl': 'African American girls',
#  'apple tree': 'Apple trees',
#  'dog': 'Dogs',
#  'fishing rod': 'Fishing rods',
#  'irrigation canal flume': 'Irrigation canals & flumes',
#  'sleeping': 'Sleeping',
#  'chicken': 'Chickens',
#  'hen': 'Hens',
#  'dice game': 'Dice games',
#  'african american child game': "African American children's games",
#  'african american preaching': 'African American preaching',
#  'african american sister': 'African American sisters',
#  'orphan': 'Orphans',
#  'african american dancer': 'African American dancers',
#  'bicycle tricycle': 'Bicycles & tricycles',
#  'farewell': 'Farewells',
#  'cry': 'Crying',
#  'watermelon': 'Watermelons',
#  'firecracker': 'Firecrackers',
#  'holiday': 'Holidays',
#  'banjo': 'banjos',
#  'drawing': 'Drawings',
#  'plow': 'Plowing',
#  'pipe smoking': 'Pipes (Smoking)',
#  'reminisce': 'Reminiscing',
#  'fish': 'Fishes',
#  'fishing hunting gear': 'Fishing & hunting gear',
#  'african american family': 'African American families',
#  'child discipline': 'Child discipline',
#  'april fool day': "April Fools' Day",
#  'doll': 'Dolls',
#  'horse': 'Horses',
#  'fishing net': 'Fishing nets',
#  'wash tub': 'Wash tubs',
#  'washboard': 'Washboards',
#  'violin': 'Violin',
#  'book': 'Books',
#  'operatic scene': 'Operatic scenes',
#  'conduct': 'Conducting',
#  'orchestra': 'Orchestra',
#  'railroad': 'Railroads',
#  'war damage': 'War damage',
#  'television broadcasting': 'Television broadcasting',
#  'music audience': 'Music audiences',
#  'opera house': 'Opera houses',
#  'father son': 'Fathers and sons',
#  'woman singer': 'Women singers',
#  'opera singer': 'Opera singers',
#  'cathedral': 'Cathedrals',
#  'franciscan': 'Franciscans',
#  'missionary': 'Missionaries',
#  'tenement house': 'Tenement houses',
#  'privy': 'Privies',
#  'clothesline': 'Clotheslines',
#  'backyard': 'Backyards',
#  'fence': 'Fences',
#  'parlor': 'Parlors',
#  'courtyard': 'Courtyards',
#  'eat drinking': 'Eating & drinking',
#  'title page': 'Title pages',
#  'donkey': 'Donkeys',
#  'owl': 'Owls',
#  'art russian': 'Art, Russian',
#  'russia': 'Russia',
#  'ukrainian': 'Ukrainian',
#  'musician': 'Musicians.',
#  'ukrainians': 'Ukrainians',
#  'mental institution': 'Mental institutions',
#  'acanthi': 'Acanthi',
#  'grotesque': 'Grotesques',
#  'staffordshire pottery': 'Staffordshire pottery',
#  'monument memorial': 'Monuments and memorials',
#  'gates': 'Gates',
#  'chapel': 'Chapels',
#  'plaza': 'Plazas',
#  'school': 'Schools',
#  'justice': 'Justice',
#  'courage': 'Courage',
#  'emblem': 'Emblems',
#  'triton greek deity': 'Triton (Greek deity)',
#  'emblem book': 'Emblem books',
#  'limestone': 'Limestone',
#  'bullfighting': 'Bullfighting',
#  'cockfighting': 'Cockfighting',
#  'cubans': 'Cubans',
#  'laborer': 'laborers',
#  'preacher': 'preachers',
#  'meeting': 'Meetings',
#  'puerto ricans': 'Puerto Ricans',
#  'population': 'Population',
#  'antiquity': 'Antiquities',
#  'nubia': 'Nubia',
#  'bas-relief': 'Bas-reliefs',
#  'temples': 'Temples',
#  'inscription': 'inscriptions',
#  'sarcophagus': 'Sarcophagi',
#  'egyptian': 'Egyptians',
#  'hathor egyptian deity': 'Hathor (Egyptian deity)',
#  'rock-cut temple': 'Rock-cut temples',
#  'pylon gateway': 'Pylons (Gateways)',
#  'colossus': 'Colossi',
#  'temple kalabsha new kalabsha egypt': 'Temple of Kalabsha (New Kalabsha, Egypt)',
#  'statue': 'Statue',
#  'pavilion': 'Pavilions',
#  'ruin': 'Ruins',
#  'sphinx': 'Sphinxes ',
#  'capital column': 'Capitals (Columns)',
#  'water supply': 'Water supply',
#  'temples nubian': 'Temples, Nubian',
#  'facade': 'Facades',
#  'column': 'Columns',
#  'newspaper carrier': 'Newspaper carriers',
#  'fishing boat': 'Fishing boats',
#  'outrigger canoe': 'Outrigger canoes',
#  'beach': 'Beaches',
#  'street railroad': 'Street railroads',
#  'moonlight': 'Moonlight',
#  'rattan palm': 'Rattan palms',
#  'broadside': 'Broadsides',
#  'rickshaw': 'Rickshaws',
#  'harvesting': 'Harvesting',
#  'sri lankans': 'Sri Lankans',
#  'tea plantation': 'Tea plantations',
#  'agricultural laborer': 'Agricultural laborers',
#  'japanese': 'Japanese',
#  'geisha': 'Geishas',
#  'manner custom': 'Manners and customs',
#  'shamisens': 'Shamisens',
#  'obi': 'Obi',
#  'kimono': 'Kimonos',
#  'clothing dress japan': 'Clothing and dress--Japan',
#  'young adult': 'Young adults',
#  'cherry tree': 'Cherry trees',
#  'pagoda': 'Pagodas',
#  'cantilever construction': 'Cantilever construction',
#  'city town life': 'City and town life',
#  'buddha': 'Buddhas',
#  'bronze sculpture japanese': 'Bronze sculpture, Japanese',
#  'architecture china': 'Architecture--China',
#  'stilt house': 'Stilt houses',
#  'tearoom': 'Tearooms',
#  'street japan': 'Streets--Japan',
#  'utility pole': 'utility poles',
#  'rock': 'Rocks',
#  'seashore': 'Seashore',
#  'buddhist temple': 'Buddhist temples',
#  'backdrop': 'backdrops',
#  'javanese indonesian people': 'Javanese (Indonesian people)',
#  'malaysian': 'Malaysians',
#  'indigenous people': 'Indigenous peoples',
#  'architecture french colonial': 'Architecture, French colonial',
#  'stūpas': 'Stūpas',
#  'roof': 'Roofs',
#  'rice': 'Rice',
#  'terrace': 'Terraces',
#  'agriculture china': 'Agriculture--China',
#  'chinese': 'Chinese',
#  'clothing dress china': 'Clothing and dress--China',
#  'footbinding': 'Footbinding',
#  'shrine': 'Shrines',
#  'tea industry': 'Tea industry',
#  'wagon train': 'Wagon trains',
#  'parasol': 'Parasols',
#  'festival japan': 'Festivals -- Japan',
#  'courtesan': 'Courtesans',
#  'bank': 'banks',
#  'cropland': 'Croplands',
#  'sugar plantation': 'Sugar plantations',
#  'shinto shrine japan': 'Shinto shrines--Japan',
#  'lakes china': 'Lakes--China',
#  'river philippine': 'Rivers--Philippines',
#  'dwelling philippine': 'Dwellings--Philippines',
#  'courthouse': 'Courthouses',
#  'sampan': 'Sampan',
#  'stele': 'Stelae',
#  'yomeimon nikko toshogu': 'Yomeimon (Nikko Toshogu)',
#  'restaurant': 'Restaurants',
#  'city town life china': 'City & town life -- China',
#  'roadside restaurant': 'Roadside restaurants',
#  'pool': 'Pools',
#  'herder': 'Herders',
#  'water buffalo': 'Water buffaloes',
#  'dirt road': 'Dirt roads',
#  'thai': 'Thai',
#  'girl': 'Girls',
#  'pergola': 'Pergolas',
#  'wisteria': 'Wisteria',
#  'leisure japan': 'Leisure -- Japan',
#  'filipinos': 'Filipinos',
#  'cover wagon': 'Covered wagons',
#  'colonial administrator': 'Colonial administrators',
#  'woman china': 'Women--China',
#  'stream': 'Streams',
#  'riparian area': 'Riparian areas',
#  'mountain sri lanka': 'Mountains--Sri Lanka',
#  'shinto shrine': 'Shinto shrines',
#  'torii': 'Torii',
#  'street china': 'Streets--China',
#  'shophouses': 'Shophouses',
#  'gamelan': 'Gamelan',
#  'trompongs': 'Trompongs',
#  'musical instrument indonesia': 'Musical instruments--Indonesia',
#  'balinese indonesian people': 'Balinese (Indonesian people)',
#  'ocean liner': 'Ocean liners',
#  'visit state': 'Visits of state',
#  'pier wharve': 'Piers & wharves',
#  'launch': 'Launching',
#  'walkway': 'Walkways',
#  'japanese tea garden': 'Japanese tea gardens',
#  'city wall': 'City walls',
#  'architecture spanish colonial': 'Architecture, Spanish colonial',
#  'sarong': 'sarongs',
#  'chinese americans': 'Chinese Americans',
#  'public building china': 'Public buildings--China',
#  'government facility': 'Government facilities',
#  'city town china': 'Cities and towns--China',
#  'bag': 'Bags',
#  'lifting carry': 'Lifting and carrying',
#  'igorot philippine people': 'Igorot (Philippine people)',
#  'clothing dress philippine': 'Clothing & dress -- Philippines',
#  'trail path': 'Trails & paths',
#  'koreans': 'Koreans',
#  'brazier': 'Braziers',
#  'sewing': 'Sewing',
#  'groom': 'Grooming',
#  'mirror': 'Mirrors',
#  'houseboat': 'Houseboats',
#  'vietnamese': 'Vietnamese',
#  'young woman': 'Young women',
#  'fan accessory': 'Fans (Accessories)',
#  'marine terminal': 'Marine terminals',
#  'warehouse': 'Warehouses',
#  'archaeological site': 'Archaeological sites',
#  'moonstone architecture': 'Moonstones (Architecture)',
#  'commercial street': 'Commercial streets',
#  'architecture colonial': 'Architecture, Colonial',
#  'dining table': 'Dining tables',
#  'old man': 'Older men',
#  'stone lantern': 'Stone lanterns',
#  'spinning': 'Spinning',
#  'rural woman': 'Rural women',
#  'springs': 'Springs',
#  'health resort': 'Health resorts',
#  'basket make': 'Basket making',
#  'vocational education': 'Vocational education',
#  'school child': 'School children',
#  'paper lantern': 'Paper lanterns',
#  'pavilion facility': 'Pavilions (Facilities)',
#  'singaporean': 'Singaporeans',
#  'palace china': 'Palaces--China',
#  'waterfront': 'Waterfronts',
#  'pedestrian mall': 'Pedestrian malls',
#  'hotel': 'Hotels',
#  'sidewalk': 'Sidewalks',
#  'food vendor': 'Food vendors',
#  'gambling': 'Gambling',
#  'lifeboat': 'Lifeboats',
#  'gangplank': 'Gangplanks',
#  'octagonal building': 'Octagonal buildings',
#  'fuelwood': 'Fuelwood',
#  'traveler tree': "Traveler's tree",
#  'tree': 'Trees',
#  'buddhist monk': 'Buddhist monks',
#  'bodhi tree': 'Bodhi Tree',
#  'buddhist temple bell': 'Buddhist temple bells',
#  'bell': 'Bells',
#  'theatrical production': 'Theatrical productions',
#  'stage platform': 'Stages (Platforms)',
#  'nō': 'Nō',
#  'theater vietnam': 'Theater--Vietnam',
#  'actor': 'Actors',
#  'beating': 'beating',
#  'punishment torture': 'Punishment & torture',
#  'open-air theatrical production': 'Open-air theatrical productions',
#  'judicial proceeding': 'Judicial proceedings',
#  'peasants': 'Peasants',
#  'ox': 'Oxen',
#  'yoke': 'Yokes',
#  'tree trunk': 'Tree trunks',
#  'cantilever bridge': 'Cantilever bridges',
#  'city town life japan': 'City & town life -- Japan',
#  'poultry': 'Poultry',
#  'public sculpture': 'Public sculpture',
#  'pedestal': 'Pedestals',
#  'irrigation': 'Irrigation',
#  'tank irrigation': 'Tank irrigation',
#  'rowboat': 'Rowboats',
#  'jetty': 'Jetties',
#  'textile industry china': 'Textile industry--China',
#  'cotton industry': 'Cotton industry',
#  'sugarcane': 'Sugarcane',
#  'sugar industry': 'Sugar industry',
#  'milling machine': 'Milling machines',
#  'river china': 'Rivers--China',
#  'bridge china': 'Bridges--China',
#  'cover bridge': 'Covered bridges',
#  'pedestrian bridge': 'Pedestrian bridges',
#  'fuelwood gathering': 'Fuelwood gathering',
#  'country life': 'Country life',
#  'minaret': 'Minarets',
#  'islamic shrine': 'Islamic shrines',
#  'maa vietnamese people': 'Maa (Vietnamese people)',
#  'dome': 'Domes',
#  'parks': 'Parks',
#  'moats': 'Moats',
#  'transportation china': 'Transportation--China',
#  'wheelbarrow': 'Wheelbarrows',
#  'porch': 'Porches',
#  'bungalow': 'Bungalows',
#  'birthday': 'Birthdays',
#  'family china': 'Families -- China',
#  'pagoda china': 'Pagodas--China',
#  'towers': 'Towers',
#  'tourist': 'Tourists',
#  'sculpture thai': 'Sculpture, Thai',
#  'bridge foundation pier': 'Bridges--Foundations and piers',
#  'rice planting rite japan': 'Rice planting rites--Japan',
#  'agricultural machinery implement': 'Agricultural machinery & implements',
#  'daijōsai': 'Daijōsai',
#  'emperor succession japan': 'Emperors--Succession--Japan',
#  'shinto priest': 'Shinto priests',
#  'shinto ritual': 'Shinto--Rituals',
#  'rice paddy': 'Rice paddies',
#  'animal team': 'Animal teams',
#  'sacrifice': 'Sacrifice',
#  'woman indonesia': 'Women--Indonesia',
#  'commercial facility': 'Commercial facilities',
#  'business district': 'Business districts',
#  'parking lot': 'Parking lots',
#  'architecture british colonial': 'Architecture, British colonial',
#  'reception room': 'Reception rooms',
#  'hair ornament': 'Hair ornaments',
#  'sauna': 'Saunas',
#  'steam': 'Steam',
#  'hot spring': 'Hot springs',
#  'official residence': 'Official residences',
#  'pile bridge': 'Pile bridges',
#  'dwelling sri lanka': 'Dwellings--Sri Lanka',
#  'reception': 'receptions',
#  'contract laborer': 'Contract laborers',
#  'sedan chair': 'Sedan chairs',
#  'wedding': 'Weddings',
#  'landscape representation': 'Landscapes (Representations)',
#  'float parade': 'Floats (Parades)',
#  'gion festival': 'Gion Festival',
#  'stone wall': 'Stone walls',
#  'cormorant': 'Cormorants',
#  'excursion boat': 'Excursion boats',
#  'spectator': 'Spectators',
#  'fishing': 'Fishing',
#  'boulder': 'Boulders',
#  'funeral rite ceremony': 'Funeral rites and ceremonies',
#  'cremation': 'Cremation',
#  'fijian': 'Fijians',
#  'toy': 'Toys',
#  'architecture japan western influence': 'Architecture--Japan--Western influences',
#  'kendhang': 'kendhang',
#  'produce stand': 'Produce stands',
#  'fruit': 'Fruit',
#  'architecture china western influence': 'Architecture--China--Western influences',
#  'handicraft': 'Handicraft',
#  'altar': 'Altars',
#  'building japan': 'Buildings -- Japan',
#  'lighthouse': 'Lighthouses',
#  'porter': 'Porters',
#  'cultural facility': 'Cultural facilities',
#  'clam': 'Clams',
#  'street light': 'Street lights',
#  'city town japan': 'Cities and towns--Japan',
#  'pedestrian': 'Pedestrians',
#  'kalinga philippine people': 'Kalinga (Philippine people)',
#  'thatch building': 'Thatched buildings',
#  'wooden building': 'Wooden buildings',
#  'robe': 'Robes',
#  'pitcher': 'Pitchers',
#  'mountain indonesia': 'Mountains--Indonesia',
#  'ferns': 'Ferns',
#  'sika deer': 'Sika deer',
#  'tea ceremony': 'tea ceremonies',
#  'bench': 'Benches',
#  'spinning apparatus': 'Spinning apparatus',
#  'sculpture japan': 'Sculpture--Japan',
#  'burmese': 'Burmese',
#  'loom': 'Looms',
#  'animal sculpture': 'Animal sculpture',
#  'crane bird': 'Cranes (Birds)',
#  'bronze china': 'Bronzes--China',
#  'banner': 'Banners',
#  'raincoat': 'Raincoats',
#  'peasants japan': 'Peasants -- Japan',
#  'straw hat': 'Straw hats',
#  'balinese indonesian people rite ceremony': 'Balinese (Indonesian people)--Rites and ceremonies',
#  'headgear': 'Headgear',
#  'dance indonesia': 'Dance -- Indonesia',
#  'ceremonial dancer': 'Ceremonial dancers',
#  'straw industry': 'Straw industries',
#  'sandal': 'Sandals',
#  'hermitage': 'Hermitages',
#  'store shop': 'Stores & shops',
#  'howdah': 'howdahs',
#  'religious procession': 'Religious processions',
#  'canopy': 'canopies',
#  'festival': 'Festivals',
#  'junk': 'Junk',
#  'taxicab': 'Taxicabs',
#  'barber': 'Barbering',
#  'city town hall': 'City & town halls',
#  'tiger': 'Tiger',
#  'dead animal': 'Dead animals',
#  'tiger hunting': 'Tiger hunting',
#  'lawn': 'Lawns',
#  'mosque': 'Mosques',
#  'winnow': 'Winnowing',
#  'durian': 'Durian',
#  'street singapore': 'Streets -- Singapore',
#  'animal traps': 'Animal traps',
#  'chrau vietnamese people': 'Chrau (Vietnamese people)',
#  'vietnam southern': 'Vietnam, Southern',
#  'trapper': 'Trappers',
#  'bamboo': 'Bamboo',
#  'equestrian statue': 'Equestrian statues',
#  'hoop': 'hoops',
#  'cobblestone street': 'Cobblestone streets',
#  'infant carrier': 'Infant carriers',
#  'umbrella': 'Umbrellas',
#  'sculpture burmese': 'Sculpture, Burmese',
#  'guardian lion': 'guardian lions',
#  'flatboat': 'Flatboats',
#  'pumpkin': 'Pumpkins',
#  'coconut plantation': 'Coconut plantations',
#  'coconut': 'Coconuts',
#  'consulate': 'consulates',
#  'tow': 'Towing',
#  'pull': 'pulling',
#  'dory boat': 'Dories (Boats)',
#  'temples china': 'Temples--China',
#  'drum': 'Drum',
#  'lantern': 'Lanterns',
#  'gantry crane': 'Gantry cranes',
#  'hoist machinery': 'Hoisting machinery',
#  'boat ship industry': 'Boat & ship industry',
#  'sea': 'Seas',
#  'beacon': 'Beacons',
#  'sailboat racing': 'Sailboat racing',
#  'outdoor cookery': 'Outdoor cookery',
#  'cookery': 'Cookery',
#  'pot pan': 'Pots & pans',
#  'woman philippine': 'Women--Philippines',
#  'bay body water': 'Bays (Bodies of water)',
#  'upper class': 'Upper class',
#  'croquet': 'Croquet',
#  'game': 'Games',
#  'mountain road': 'Mountain roads',
#  'bull': 'Bulls',
#  'animal feeding': 'Animal feeding',
#  'lion art': 'Lions in art',
#  'castles palace japan': 'Castles & palaces -- Japan',
#  'pump station': 'Pumping stations',
#  'card game': 'Card games',
#  'utagaruta game': 'Utagaruta (Game)',
#  'trellis': 'Trellises',
#  'opium trade china': 'Opium trade--China',
#  'hulk': 'hulks',
#  'sinhalese sri lankan people': 'Sinhalese (Sri Lankan people)',
#  'musical instrument japan': 'Musical instruments--Japan',
#  'kotsuzumi': 'Kotsuzumi',
#  'hourglass drum': 'Hourglass drum',
#  'taiko': 'Taiko',
#  'demon': 'Demons',
#  'mask japan': 'Masks -- Japan',
#  'cargo ship': 'Cargo ships',
#  'industries china': 'Industries--China',
#  'wheelwright': 'Wheelwrights',
#  'cattle': 'Cattle',
#  'loading dock': 'Loading docks',
#  'cocoa industry': 'Cocoa industry',
#  'azalea': 'Azaleas',
#  'court courtier': 'Court and courtiers',
#  'work elephant': 'Working elephants',
#  'infant': 'Infants',
#  'gardens china': 'Gardens--China',
#  'pavilion china': 'Pavilions--China',
#  'curb': 'Curbs',
#  'parade procession': 'Parades & processions',
#  'boatman': 'Boatmen',
#  'rapids': 'Rapids',
#  'boundary wall': 'Boundary walls',
#  'buddhist sculpture': 'Buddhist sculpture',
#  'building construction': 'Building construction',
#  'indigenous people malaysia': 'Indigenous peoples -- Malaysia',
#  'cacao': 'Cacao',
#  'cupola': 'Cupolas',
#  'embroidery': 'Embroidery',
#  'stove': 'Stoves',
#  'ming tombs china': 'Ming Tombs (China)',
#  'obelisk': 'Obelisks',
#  'japanese black pine': 'Japanese black pine',
#  'historic tree': 'Historic trees',
#  'shoe': 'Shoes',
#  'storefront': 'Storefronts',
#  'hat': 'Hats',
#  'vehicle': 'Vehicles',
#  'woman samoan': 'Women, Samoan',
#  'samoan': 'Samoans',
#  'industrial facility': 'Industrial facilities',
#  'artisan': 'Artisans',
#  'textile painting': 'Textile painting',
#  'fabric shop': 'Fabric shops',
#  'door doorway': 'Doors & doorways',
#  'electric sign': 'Electric signs',
#  'beer hall': 'Beer halls',
#  'bowhunters': 'Bowhunters',
#  'vedda sri lankan people': 'Vedda (Sri Lankan people)',
#  'bow arrow': 'Bow and arrow',
#  'rock garden': 'Rock gardens',
#  'vase': 'Vases',
#  'driveway': 'Driveways',
#  'child philippine': 'Children--Philippines',
#  'flag united state': 'Flags--United States',
#  'cook islander': 'Cook Islanders',
#  'loggia': 'Loggias',
#  'buddhist decoration ornament': 'Buddhist decoration and ornament',
#  'sawmill': 'Sawmills',
#  'theatrical producer director': 'Theatrical producers and directors',
#  'actress': 'Actresses',
#  'arhats art': 'Arhats in art',
#  'ox art': 'Oxen in art',
#  'stone bridge': 'Stone bridges',
#  'thresh': 'Threshing',
#  'wheat': 'Wheat',
#  'tropics': 'Tropics',
#  'carriage coach': 'Carriages & coaches',
#  'radish': 'Radishes',
#  'food dry': 'Food drying',
#  'channel': 'Channels',
#  'river vietnam': 'Rivers--Vietnam',
#  'russo-japanese war 1904-1905 campaign china': 'Russo-Japanese War, 1904-1905--Campaigns--China',
#  'motorboat': 'Motorboats',
#  'suspension bridge': 'Suspension bridges',
#  'food processing': 'Food processing',
#  'hulling': 'Hulling',
#  'mortar pestle': 'Mortars & pestles',
#  'fraternal lodge': 'Fraternal lodges',
#  'masonic building': 'Masonic buildings',
#  'sail': 'Sails',
#  'agriculture japan': 'Agriculture--Japan',
#  'accordion': 'accordions',
#  'cliff': 'Cliffs',
#  'row house': 'Row houses',
#  'tombs china': 'Tombs--China',
#  'dugout canoe': 'Dugout canoes',
#  'sunrise sunset': 'Sunrises & sunsets',
#  'farmer china': 'Farmers--China',
#  'throne': 'Thrones',
#  'palace burma': 'Palaces--Burma',
#  'fishing village': 'Fishing villages',
#  'smile': 'Smiling',
#  'street vendor': 'Street vendors',
#  'volcano': 'Volcanoes',
#  'gallery museum': 'Galleries & museums',
#  'interior decoration japan': 'Interior decoration--Japan',
#  'koto japanese zither': 'Kotos (Japanese zither)',
#  'ford stream crossing': 'Fords (Stream crossings)',
#  'child laborer': 'Child laborers',
#  'mint': 'Mints',
#  'smokestack': 'smokestacks',
#  'fish pond': 'Fish ponds',
#  'eel fishing': 'Eel fishing',
#  'parks china': 'Parks--China',
#  'storehouse': 'Storehouses',
#  'confucian temple': 'Confucian temples',
#  'bridge japan inland sea': 'Bridges--Japan--Inland Sea',
#  'waitress': 'Waitresses',
#  'pass landform': 'Passes (Landforms)',
#  'rake sweeping': 'Raking (Sweeping)',
#  'straw': 'Straw',
#  'indonesia social life custom': 'Indonesia--Social life and customs',
#  'headgear indonesia': 'Headgear--Indonesia',
#  'costume indonesia': 'Costume--Indonesia',
#  'oil well': 'Oil wells',
#  'petroleum worker': 'Petroleum workers',
#  'oil well drilling rig': 'Oil well drilling rigs',
#  'horn anatomy': 'Horns (Anatomy)',
#  'banana plant': 'Banana plants',
#  'stūpas miniature': 'Stūpas, Miniature',
#  'reliquary': 'Reliquaries',
#  'city hall': 'City halls',
#  'monastery': 'Monasteries',
#  'buddhist monastery': 'Buddhist monasteries',
#  'commercial building': 'Commercial buildings',
#  'nagoyajō nagoya-shi japan': 'Nagoyajō (Nagoya-shi, Japan)',
#  'canal china': 'Canals--China',
#  'log': 'logs',
#  'watch tower': 'Watch towers',
#  'swine': 'Swine',
#  'spit': 'spits',
#  'ox team': 'Ox teams',
#  'ice cream ice': 'Ice cream & ices',
#  'shopping': 'Shopping',
#  'tropical forest': 'Tropical forests',
#  'gutter street': 'Gutters (Streets)',
#  'animal mythical': 'Animals, Mythical',
#  'mallet': 'Mallets',
#  'screen': 'Screens',
#  'coal': 'Coaling',
#  'reflection': 'Reflections',
#  'musical instrument burma': 'Musical instruments--Burma',
#  'hindu temple': 'Hindu temples',
#  'funeral procession': 'Funeral processions',
#  'clock tower': 'Clock towers',
#  'awning': 'Awnings',
#  'cartouche architecture': 'Cartouches (Architecture)',
#  'stone building': 'Stone buildings',
#  'prang': 'prang',
#  'road singapore': 'Roads--Singapore',
#  'hotel china': 'Hotels--China',
#  'marriage': 'Marriage',
#  'grooms wedding': 'Grooms (Weddings)',
#  'bride': 'Brides',
#  'bedroom': 'Bedrooms',
#  'thaipusam': 'Thaipusam',
#  'hinduism': 'Hinduism',
#  'chetties': 'Chetties',
#  'cover walk': 'Covered walks',
#  'padaung burmese people': 'Padaung (Burmese people)',
#  ...}

# %%
with open('analyzed_topics.json', 'w') as outfile:
    json.dump(new_topics, outfile)

# %% [markdown]
# Загружаем словарь вида: обработанный топик - исходный топик:

# %%
new_topics = json.loads(open('analyzed_topics.json').read())

# %% [markdown]
# Загружаем модель (основанную на английской википедии):

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
model = gensim.models.KeyedVectors.load_word2vec_format(os.path.join('word2vec_models','enwiki_5_ner.bin'), binary=True)
# Out:
# 2017-05-23 16:43:34,816 : INFO : loading projection weights from word2vec_models\enwiki_5_ner.bin
# 2017-05-23 16:45:13,431 : INFO : loaded (296630, 300) matrix from word2vec_models\enwiki_5_ner.bin

# %%
model.init_sims(replace=True)
# Out:
# 2017-05-23 16:46:50,161 : INFO : precomputing L2-norms of word weight vectors

# %% [markdown]
# Проверяем, есть ли в модели коллокации, разделённые пробелами:

# %%
for word in model.vocab:
    if ' ' in word:
        print(word)

# %% [markdown]
# Функция ищет topn ближайших по косинусному расстоянию слов; ищет эти слова в топиках; возвращает первые resultsn топиков, в которых нашлись эти "синонимы"

# %%
pos_tags = ['ADJ', 'ADV', 'NOUN', 'PROPN', 'VERB']

def sim_word2vec(word, topn=10, resultsn=10):
    global pos_tags
    results = []

    for pos_tag in pos_tags:
#         print(pos_tag)
        word_tagged = word.replace(' ', '::') + '_' + pos_tag
        if word_tagged in model:
            for i in model.most_similar(positive=[word_tagged], topn = topn):
                sim_word = i[0].split('_')[0].replace('::', '(-| )')
#                 print(i)
                for topic in new_topics:
                    n = re.search('(\s|^)' + sim_word.lower() + '(\s|$)', topic)
                    if n is not None:
                        result = new_topics[topic]
                        if result not in results:
                            results.append(result)
                        if len(results) > resultsn:
                            return results
    return results

# %%
sim_word2vec('boy', 10, 10)
# Out:
# ['African American girls',
#  'Girls',
#  'Chorus girls',
#  'Girl Scouts',
#  'Infant girls',
#  'Teenage girls',
#  'Girls -- United States -- 1890-1899',
#  'Girls -- 1900-1909',
#  'Girls -- 1910-1919',
#  'Gibson girls',
#  'Girls -- 1870-1879']
